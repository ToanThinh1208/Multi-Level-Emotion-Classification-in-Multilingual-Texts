# %%
# %pip install wordcloud
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# Out:
# Requirement already satisfied: wordcloud in d:\envs\py310_env\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from wordcloud) (2.2.3)
# Requirement already satisfied: pillow in d:\envs\py310_env\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in d:\envs\py310_env\lib\site-packages (from wordcloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\envs\py310_env\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\envs\py310_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in d:\envs\py310_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in d:\envs\py310_env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\envs\py310_env\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\envs\py310_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\envs\py310_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\envs\py310_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\envs\py310_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in d:\envs\py310_env\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\envs\py310_env\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\envs\py310_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\envs\py310_env\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in d:\envs\py310_env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\envs\py310_env\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\envs\py310_env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\envs\py310_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\envs\py310_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\ncpc\appdata\roaming\python\python310\site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in d:\envs\py310_env\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\envs\py310_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\envs\py310_env\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\envs\py310_env\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\envs\py310_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt
import string
import re
from collections import Counter

#đọc file
df = pd.read_csv("./dataset_vi/Amazon_Product_Review_full_vi_cleaned.csv")
# Xác định cột chứa nội dung review: ưu tiên 'review_body', sau đó 'review_headline'
if 'review_headline' in df.columns:
    review_col = 'review_headline'
elif 'review_body' in df.columns:
    review_col = 'review_body'
else:
    raise Exception("Không tìm thấy cột review (expected 'review_body', 'review_headline')")

# %%
print("=== Thông tin dataset ===")
df.info()
# Out:
# === Thông tin dataset ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30846 entries, 0 to 30845
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        30846 non-null  object
#  1   customer_id        30846 non-null  int64
#  2   review_id          30846 non-null  object
#  3   product_id         30846 non-null  object
#  4   product_parent     30846 non-null  int64
#  5   product_title      30846 non-null  object
#  6   product_category   30846 non-null  object
#  7   star_rating        30846 non-null  int64
#  8   helpful_votes      30846 non-null  int64
#  9   total_votes        30846 non-null  int64
#  10  vine               30846 non-null  object
#  11  verified_purchase  30846 non-null  object
#  12  review_headline    30831 non-null  object
#  13  review_body        30819 non-null  object
#  14  review_date        30846 non-null  object
#  15  sentiment          30846 non-null  int64
# dtypes: int64(6), object(10)
# memory usage: 3.8+ MB

# %%
#Kiểm tra dữ liệu trùng lặp
duplicates = df.duplicated().sum()
print(f"\nSố dòng dữ liệu trùng lặp: {duplicates}")
# Out:
# Số dòng dữ liệu trùng lặp: 0

# %%
# Kiểm tra số lượng giá trị null theo từng cột
print("\nSố lượng giá trị null theo cột:")
print(df.isnull().sum())
# Out:
# Số lượng giá trị null theo cột:
# marketplace           0
# customer_id           0
# review_id             0
# product_id            0
# product_parent        0
# product_title         0
# product_category      0
# star_rating           0
# helpful_votes         0
# total_votes           0
# vine                  0
# verified_purchase     0
# review_headline      15
# review_body          27
# review_date           0
# sentiment             0
# dtype: int64

# %%
# 4. Vẽ heatmap mối tương quan giữa các cột số
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
if numeric_cols:
    plt.figure(figsize=(8,6))
    corr = df[numeric_cols].corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm')
    plt.title("Heatmap tương quan giữa các biến số")
    plt.show()

# %%
# 1. Phân loại star_rating theo product_category
# -------------------------------

plt.figure(figsize=(12,6))
sns.countplot(data=df, x='product_category', hue='star_rating')
plt.title('Phân loại star_rating theo product_category')
plt.xlabel('Product Category')
plt.ylabel('Số lượng đánh giá')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1. Phân tích mối quan hệ giữa star_rating và review_body
# Biểu đồ đếm số lượng review theo từng star_rating
plt.figure(figsize=(8, 6))
sns.countplot(x='star_rating', data=df, palette='viridis')
plt.title('Số lượng review theo star_rating')
plt.xlabel('Star Rating')
plt.ylabel('Số lượng review')
plt.show()
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\2769464641.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='star_rating', data=df, palette='viridis')

# %%
# Tạo cột review_length: đếm số từ trong nội dung review
df['review_length'] = df[review_col].apply(lambda x: len(str(x).split()))
print("\nMô tả của review_length:")
print(df['review_length'].describe())
# 3. Barplot: Độ dài review trung bình theo Rating Star
avg_review_length = df.groupby('star_rating')['review_length'].mean().reset_index()
plt.figure(figsize=(8,6))
sns.barplot(x='star_rating', y='review_length', data=avg_review_length, palette="magma")
plt.title("Độ Dài Review Trung Bình Theo Rating Star")
plt.xlabel("Rating Star")
plt.ylabel("Độ Dài Review Trung Bình (Số Từ)")
plt.tight_layout()
plt.show()
# Out:
# Mô tả của review_length:
# count    30846.000000
# mean         5.664332
# std          5.103273
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          8.000000
# max         41.000000
# Name: review_length, dtype: float64
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\2431275240.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='star_rating', y='review_length', data=avg_review_length, palette="magma")

# %%
# Danh sách stopwords cơ bản (bạn có thể mở rộng danh sách này nếu cần)
default_stopwords = set(["the", "and", "a", "an", "in", "of", "to", "is", "it", "that", "for", "with", "on", "this"])

# Hàm tokenize: chuyển văn bản về chữ thường, loại bỏ dấu câu và stopwords
def tokenize(text):
    text = str(text).lower()  # chuyển về chữ thường
    text = re.sub(f"[{re.escape(string.punctuation)}]", " ", text)  # loại bỏ dấu câu
    tokens = text.split()
    tokens = [t for t in tokens if t not in default_stopwords]  # loại bỏ stopwords
    return tokens

# Lấy danh sách các rating có trong dữ liệu, giả sử cột đánh giá là 'star_rating'
ratings = sorted(df['star_rating'].unique())
word_freq_dict = {}

for r in ratings:
    # Lấy các review tương ứng với rating r
    texts = df[df['star_rating'] == r][review_col].dropna().tolist()
    all_tokens = []
    for text in texts:
        all_tokens.extend(tokenize(text))
    # Đếm tần suất từ
    counter = Counter(all_tokens)
    common_words = counter.most_common(10)  # Lấy 10 từ xuất hiện nhiều nhất
    word_freq_dict[r] = common_words

# Vẽ biểu đồ cho từng mức rating
num_ratings = len(ratings)
fig, axes = plt.subplots(num_ratings, 1, figsize=(10, 5 * num_ratings))
if num_ratings == 1:
    axes = [axes]

for i, r in enumerate(ratings):
    if word_freq_dict[r]:
        words, counts = zip(*word_freq_dict[r])
    else:
        words, counts = ([], [])
    sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
    axes[i].set_title(f"Top 10 từ thường gặp với Rating Star {r}")
    axes[i].set_xlabel("Tần Số")
    axes[i].set_ylabel("Từ")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\3387660300.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\3387660300.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\3387660300.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\3387660300.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_14120\3387660300.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
